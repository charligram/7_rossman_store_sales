# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Importar dataframe

# %%
DATA_PROCESSED_ROUTE = r"../data/processed/df_processed.csv"

# %%
df = pd.read_csv(DATA_PROCESSED_ROUTE)
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_29180\2381288091.py:1: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATA_PROCESSED_ROUTE)
